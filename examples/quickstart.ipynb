# %% [markdown]
# # cks-keywords quickstart
# This notebook loads the frozen Paper-1 profile. Raw-text extraction requires `en_core_web_sm`.

# %%
from cks_keywords import FrozenCKS
cks = FrozenCKS.from_profile('paper1-w050-s40')
cks.verify_manifest()

# %%
abstract = 'This study examines phonological structure, handshape, and movement in sign language.'
result = cks.extract_keywords(abstract, title='Sign language phonology', top_n=10)
result[['candidate_display', 'candidate_score', 'candidate_rank']]
